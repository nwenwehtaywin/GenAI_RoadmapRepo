# %%
# !pip install huggingface-hub

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3.5-mini-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct")

messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Can you provide ways to eat combinations of bananas and dragonfruits?"},
    {"role": "assistant", "content": "Sure! Here are some ways to eat bananas and dragonfruits together: 1. Banana and dragonfruit smoothie: Blend bananas and dragonfruits together with some milk and honey. 2. Banana and dragonfruit salad: Mix sliced bananas and dragonfruits together with some lemon juice and honey."},
    {"role": "user", "content": "What is the square value 3"},
]

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

output = pipe(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
from huggingface_hub import login
login()

# %%
from huggingface_hub import whoami
whoami=whoami()
print(whoami)
# Out:
# {'type': 'user', 'id': '64cbb46640ce646cc7e2356b', 'name': 'nnhwin', 'fullname': 'Nwe Win', 'isPro': False, 'avatarUrl': '/avatars/84cbf37904a073dc3ead604870fafc5b.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'parami', 'role': 'fineGrained', 'createdAt': '2025-04-04T05:55:09.223Z', 'fineGrained': {'canReadGatedRepos': False, 'global': [], 'scoped': [{'entity': {'_id': '64cbb46640ce646cc7e2356b', 'type': 'user', 'name': 'nnhwin'}, 'permissions': []}]}}}}

# %%
from huggingface_hub import HfApi, HfFolder

# Set your token (you can generate a token in your Hugging Face account settings)
token = "" #use your token
HfFolder.save_token(token)  # Save the token locally

# Or pass the token directly to the API call
api = HfApi(token=token)
api.upload_file(
    path_or_fileobj="aws.pdf",
    path_in_repo='aws.pdf',
    repo_id="nnhwin/pdf",
    repo_type="model" #dataset
)
# Out:
# aws.pdf:   0%|          | 0.00/1.89M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/nnhwin/pdf/commit/9762faaf6510af27912dd6ff1a288a1568208ede', commit_message='Upload aws.pdf with huggingface_hub', commit_description='', oid='9762faaf6510af27912dd6ff1a288a1568208ede', pr_url=None, pr_revision=None, pr_num=None)
